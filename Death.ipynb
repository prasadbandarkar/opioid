# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Multiple_Cause_of_Death_1999-2017.txt',sep='\t',index_col=['County','Year'],nrows=266)

# %%
df1.tail(20)
# Out:
#                            Notes  County Code  Year Code      Deaths  \
# County               Year
# Suffolk County, MA   2017    NaN        25025       2017         230
# Worcester County, MA 1999    NaN        25027       1999  Suppressed
#                      2000    NaN        25027       2000          10
#                      2001    NaN        25027       2001  Suppressed
#                      2002    NaN        25027       2002          12
#                      2003    NaN        25027       2003          10
#                      2004    NaN        25027       2004  Suppressed
#                      2005    NaN        25027       2005          14
#                      2006    NaN        25027       2006          27
#                      2007    NaN        25027       2007          32
#                      2008    NaN        25027       2008          29
#                      2009    NaN        25027       2009          23
# ...

# %%
after_2005=df1.loc[( 'Suffolk County, MA' , ['2005','2006']),:]

# %%
after_2006=df1.xs(2006,level='Year')

# %%
after_2008=df1.loc[( slice(None), list(range(2008,2018))  ),:]

# %%
after_2008
# Out:
#                             Notes  County Code  Year Code      Deaths  \
# County                Year
# Barnstable County, MA 2008    NaN        25001       2008  Suppressed
#                       2009    NaN        25001       2009  Suppressed
#                       2010    NaN        25001       2010          14
#                       2011    NaN        25001       2011          18
#                       2012    NaN        25001       2012          13
# ...                           ...          ...        ...         ...
# Worcester County, MA  2013    NaN        25027       2013          51
#                       2014    NaN        25027       2014          84
#                       2015    NaN        25027       2015         173
#                       2016    NaN        25027       2016         181
#                       2017    NaN        25027       2017         228
#
#                             Population  Crude Rate
# County                Year
# ...
